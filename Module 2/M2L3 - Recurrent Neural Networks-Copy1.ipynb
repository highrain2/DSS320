# %% [markdown]
# # Recurrent Neural Networks
# RNNs are useful when we're dealing with serial data, such as time-based data, where predictions of future events are based on the combination of past inputs.  For example
# * a browser may suggest the next word based on the last three words you already typed in a search bar
# * the next position of a vehicle may be dependent on a certain number of past position measurements
# * value for a a repeating signal such as a sinusoid requires learning the past signal shape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# Workshop Functions
import sys
sys.path.append('..')
from WKDSS320_functions import *

# %%
# some more libraries specifically for RNNs
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math

# %% [markdown]
# ## Sunspot Prediction
# Using historical data on sunspot sightings, try predicting when the next one will happen
# Information on the dataset, which comes standard in the R programming suite, can be found here: https://r-data.pmagunia.com/dataset/r-dataset-package-datasets-sunspots

# %%
df = pd.read_csv('sunspots.csv')
df.head()
data = df.loc[:,'Sunspots'] #we just need the sunpot code, not the month and year.  
                            #Knowing that each entry is a month apart from the next one is sufficient.
plt.figure(figsize=(16,5))
plt.plot(data)
plt.title('Sunspot data showing clear cyclic pattern')
plt.show()

# %%
#data = np.array(data)
data = np.array(data.values.astype('float32'))
data = data.reshape(len(data),1)

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data).flatten()
data
# Out:
# array([0.22852638, 0.24665089, 0.2758077 , ..., 0.21985814, 0.13120566,
#        0.13159968], dtype=float32)

# %%
# We can't use train_test_split to randomly split the data, since we need to maintain it's serial nature.  
# So let's split so that the first X% of data will be the training set, and the remaining datapoints after will be the test set.  
split_pcnt = 70
split = int(len(data)*split_pcnt/100)
Train = data[range(split)]
Test = data[split:]

# %% [markdown]
# Reshape the data from one long array to a matrix of dimensions 187 (years) x 12 (months) x 1 (# variables)

# %%
# get indices for 13th month (remember 0-based indexing) as target for RNN to predict
time_steps = 12
Y_ind = np.arange(time_steps, len(Train), time_steps)
YTrain = Train[Y_ind]

# reshape XTrain to 3 dim matrix
rows_x = len(YTrain)
XTrain = Train[range(time_steps*rows_x)] #keep the largest multiple of 12, discard the rest
XTrain = np.reshape(XTrain, (rows_x, time_steps, 1))  #reshape to a matrix

# %%
# Repeat for test data:
Y_ind = np.arange(time_steps, len(Test), time_steps)
YTest = Test[Y_ind]

# reshape XTrain to 3 dim matrix
rows_x = len(YTest)
XTest = Test[range(time_steps*rows_x)] #keep the largest multiple of 12, discard the rest
XTest = np.reshape(XTest, (rows_x, time_steps, 1))  #reshape to a matrix

# %% [markdown]
# RNN will have:
# * 3 hidden layers
# * hidden layers will have 12 steps
# * 1 dense output layer.
# * tanh activation functions for hidden and output layers

# %%
from tensorflow.keras.layers import Dropout
hidden_units = 12
input_shape = (1,1)
model = Sequential()
model.add(SimpleRNN(hidden_units, input_shape=input_shape, activation='tanh'))

# model.add(Dropout(0.5)) # Not using dropout because model is not overfitting...
# and it lowers performance by 2x.  Also with only 3 hidden layers, there's not...
# room to randomly shut off 50% of 3 layers.  

model.add(Dense(units=1,activation='tanh'))
model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(XTrain, YTrain, epochs=50, validation_data=(XTest,YTest),
          batch_size=1, verbose=2)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_268\47123064.py in <module>
#      12 model.compile(loss='mean_squared_error', optimizer='adam')
#      13
# ---> 14 model.fit(XTrain, YTrain, epochs=50, validation_data=(XTest,YTest),
#      15           batch_size=1, verbose=2)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\hiren\anaconda3\lib\site-packages\keras\engine\training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\hiren\anaconda3\lib\site-packages\keras\engine\training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\hiren\anaconda3\lib\site-packages\keras\engine\training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\hiren\anaconda3\lib\site-packages\keras\engine\training.py", line 1050, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\hiren\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\hiren\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_1" is incompatible with the layer: expected shape=(None, 1, 1), found shape=(1, 12, 1)

# %%
# make predictions
train_predict = model.predict(XTrain)
test_predict = model.predict(XTest)

# Error of predictions
train_rmse = math.sqrt(mean_squared_error(YTrain, train_predict))
test_rmse = math.sqrt(mean_squared_error(YTest, test_predict))
# Print RMSE
print('Train RMSE: %.3f RMSE' % (train_rmse))
print('Test RMSE: %.3f RMSE' % (test_rmse))
# Out:
# 6/6 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# Train RMSE: 0.061 RMSE
# Test RMSE: 0.084 RMSE

# %%
plt.figure(figsize=(10,6))
plt.plot(range(len(YTest)),YTest)
plt.plot(range(len(test_predict)),test_predict)
plt.xlabel('Observation number after given time steps')
plt.ylabel('Sunspots scaled')
plt.title('Actual and Predicted Values of Test Set')
plt.legend(['Actual', 'Predictions'])
plt.show()

# %% [markdown]
# ### LSTM Example
# We are covering the theory of LSTM's, but we can go over an example of how to use it.

# %%
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import BatchNormalization
from keras.losses import SparseCategoricalCrossentropy
model = Sequential()
model.add(LSTM(3, input_shape=(time_steps,1)))
model.add(Dense(units=1,activation='tanh'))
print(model.summary())

model.compile(
    loss='mean_squared_error',
    optimizer="adam",
)

model.fit(XTrain, YTrain, epochs=50, validation_data=(XTest,YTest),
          batch_size=1, verbose=2)

# make predictions
train_predict = model.predict(XTrain)
test_predict = model.predict(XTest)

# Error of predictions
train_rmse = math.sqrt(mean_squared_error(YTrain, train_predict))
test_rmse = math.sqrt(mean_squared_error(YTest, test_predict))
# Print RMSE
print('Train RMSE: %.3f RMSE' % (train_rmse))
print('Test RMSE: %.3f RMSE' % (test_rmse))
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 3)                 60
#
#  dense_34 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 164/164 - 2s - loss: 0.0112 - val_loss: 0.0222 - 2s/epoch - 13ms/step
# Epoch 2/50
# 164/164 - 1s - loss: 0.0073 - val_loss: 0.0138 - 549ms/epoch - 3ms/step
# Epoch 3/50
# 164/164 - 1s - loss: 0.0054 - val_loss: 0.0096 - 543ms/epoch - 3ms/step
# Epoch 4/50
# 164/164 - 1s - loss: 0.0047 - val_loss: 0.0099 - 545ms/epoch - 3ms/step
# Epoch 5/50
# 164/164 - 1s - loss: 0.0047 - val_loss: 0.0076 - 541ms/epoch - 3ms/step
# Epoch 6/50
# 164/164 - 1s - loss: 0.0045 - val_loss: 0.0071 - 545ms/epoch - 3ms/step
# Epoch 7/50
# 164/164 - 1s - loss: 0.0043 - val_loss: 0.0071 - 536ms/epoch - 3ms/step
# Epoch 8/50
# 164/164 - 1s - loss: 0.0043 - val_loss: 0.0075 - 541ms/epoch - 3ms/step
# Epoch 9/50
# 164/164 - 1s - loss: 0.0042 - val_loss: 0.0084 - 561ms/epoch - 3ms/step
# Epoch 10/50
# 164/164 - 1s - loss: 0.0041 - val_loss: 0.0066 - 571ms/epoch - 3ms/step
# Epoch 11/50
# 164/164 - 1s - loss: 0.0040 - val_loss: 0.0078 - 573ms/epoch - 3ms/step
# Epoch 12/50
# 164/164 - 1s - loss: 0.0042 - val_loss: 0.0063 - 567ms/epoch - 3ms/step
# Epoch 13/50
# 164/164 - 1s - loss: 0.0039 - val_loss: 0.0054 - 567ms/epoch - 3ms/step
# Epoch 14/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0056 - 569ms/epoch - 3ms/step
# Epoch 15/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0070 - 567ms/epoch - 3ms/step
# Epoch 16/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0071 - 562ms/epoch - 3ms/step
# Epoch 17/50
# 164/164 - 1s - loss: 0.0039 - val_loss: 0.0052 - 570ms/epoch - 3ms/step
# Epoch 18/50
# 164/164 - 1s - loss: 0.0037 - val_loss: 0.0057 - 547ms/epoch - 3ms/step
# Epoch 19/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0070 - 556ms/epoch - 3ms/step
# Epoch 20/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0055 - 556ms/epoch - 3ms/step
# Epoch 21/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0050 - 572ms/epoch - 3ms/step
# Epoch 22/50
# 164/164 - 1s - loss: 0.0039 - val_loss: 0.0049 - 553ms/epoch - 3ms/step
# Epoch 23/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0059 - 588ms/epoch - 4ms/step
# Epoch 24/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0054 - 559ms/epoch - 3ms/step
# Epoch 25/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0059 - 571ms/epoch - 3ms/step
# Epoch 26/50
# 164/164 - 1s - loss: 0.0037 - val_loss: 0.0051 - 573ms/epoch - 3ms/step
# Epoch 27/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0053 - 601ms/epoch - 4ms/step
# Epoch 28/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0054 - 595ms/epoch - 4ms/step
# Epoch 29/50
# 164/164 - 1s - loss: 0.0037 - val_loss: 0.0061 - 630ms/epoch - 4ms/step
# Epoch 30/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0061 - 612ms/epoch - 4ms/step
# Epoch 31/50
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0059 - 556ms/epoch - 3ms/step
# Epoch 32/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0056 - 744ms/epoch - 5ms/step
# Epoch 33/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0053 - 706ms/epoch - 4ms/step
# Epoch 34/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0061 - 704ms/epoch - 4ms/step
# Epoch 35/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0073 - 647ms/epoch - 4ms/step
# Epoch 36/50
# 164/164 - 1s - loss: 0.0037 - val_loss: 0.0060 - 557ms/epoch - 3ms/step
# Epoch 37/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0062 - 589ms/epoch - 4ms/step
# Epoch 38/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0061 - 687ms/epoch - 4ms/step
# Epoch 39/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0060 - 649ms/epoch - 4ms/step
# Epoch 40/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0054 - 675ms/epoch - 4ms/step
# Epoch 41/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0053 - 728ms/epoch - 4ms/step
# Epoch 42/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0062 - 643ms/epoch - 4ms/step
# Epoch 43/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0056 - 572ms/epoch - 3ms/step
# Epoch 44/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0058 - 583ms/epoch - 4ms/step
# Epoch 45/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0066 - 551ms/epoch - 3ms/step
# Epoch 46/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0062 - 585ms/epoch - 4ms/step
# Epoch 47/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0057 - 550ms/epoch - 3ms/step
# Epoch 48/50
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0057 - 546ms/epoch - 3ms/step
# Epoch 49/50
# 164/164 - 1s - loss: 0.0034 - val_loss: 0.0055 - 550ms/epoch - 3ms/step
# Epoch 50/50
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0055 - 601ms/epoch - 4ms/step
# 6/6 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 3ms/step
# Train RMSE: 0.057 RMSE
# Test RMSE: 0.074 RMSE

# %% [markdown]
# ### RNN with DPA Data
# ***curiosity points (15 points)***
# Load the shortened DPA dataset (59 time-series variables) and try to predict the hamming weight using a simple RNN network.  Solution shown below.

# %%
# Read in the DPA datasest from Module 1
X = pd.read_csv("DPA_Data_Small.csv").values
y = pd.read_csv("DPA_target.csv", index_col=0)
y = np.array(y).ravel()

# %%
class1 = 2
class2 = 6

# %%
X_2class = X[((y==class1) | (y==class2)),:]
y_2class = y[(y==class1) | (y==class2)]
X_2class.shape
# Out:
# (224, 59)

# %%
# Need to convert classes to 0 and 1
y_2class[y_2class==class1]=0
y_2class[y_2class==class2]=1

# %%
# Split to training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_2class, y_2class, test_size=0.3, random_state=1)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
nrow,ncol = X_train.shape
X_train = np.reshape(X_train, (nrow, ncol, 1)) 
nrow,ncol = X_test.shape
X_test = np.reshape(X_test, (nrow, ncol, 1))

# %%
hidden_units = 3
input_shape = (ncol,1)
model = Sequential()
model.add(SimpleRNN(hidden_units, input_shape=input_shape, activation='tanh'))

# model.add(Dropout(0.5)) # Not using dropout because model is not overfitting...
# and it lowers performance by 2x.  Also with only 3 hidden layers, there's not...
# room to randomly shut off 50% of 3 layers.  

model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

model.fit(X_train, y_train, epochs=50, validation_data=(X_test,y_test),
          batch_size=1, verbose=2)
# Out:
# Epoch 1/50
# 156/156 - 2s - loss: 0.7187 - val_loss: 0.6881 - 2s/epoch - 12ms/step
# Epoch 2/50
# 156/156 - 1s - loss: 0.7046 - val_loss: 0.6827 - 935ms/epoch - 6ms/step
# Epoch 3/50
# 156/156 - 1s - loss: 0.6937 - val_loss: 0.6746 - 930ms/epoch - 6ms/step
# Epoch 4/50
# 156/156 - 1s - loss: 0.6758 - val_loss: 0.6471 - 943ms/epoch - 6ms/step
# Epoch 5/50
# 156/156 - 1s - loss: 0.6239 - val_loss: 0.5771 - 963ms/epoch - 6ms/step
# Epoch 6/50
# 156/156 - 1s - loss: 0.5826 - val_loss: 0.5564 - 962ms/epoch - 6ms/step
# Epoch 7/50
# 156/156 - 1s - loss: 0.5615 - val_loss: 0.5407 - 947ms/epoch - 6ms/step
# Epoch 8/50
# 156/156 - 1s - loss: 0.5454 - val_loss: 0.5282 - 928ms/epoch - 6ms/step
# Epoch 9/50
# 156/156 - 1s - loss: 0.5382 - val_loss: 0.5151 - 926ms/epoch - 6ms/step
# Epoch 10/50
# 156/156 - 1s - loss: 0.5202 - val_loss: 0.5043 - 935ms/epoch - 6ms/step
# Epoch 11/50
# 156/156 - 1s - loss: 0.5063 - val_loss: 0.4850 - 934ms/epoch - 6ms/step
# Epoch 12/50
# 156/156 - 1s - loss: 0.4919 - val_loss: 0.4662 - 934ms/epoch - 6ms/step
# Epoch 13/50
# 156/156 - 1s - loss: 0.4719 - val_loss: 0.4350 - 926ms/epoch - 6ms/step
# Epoch 14/50
# 156/156 - 1s - loss: 0.4422 - val_loss: 0.3873 - 922ms/epoch - 6ms/step
# Epoch 15/50
# 156/156 - 1s - loss: 0.3862 - val_loss: 0.3235 - 938ms/epoch - 6ms/step
# Epoch 16/50
# 156/156 - 1s - loss: 0.3207 - val_loss: 0.2772 - 940ms/epoch - 6ms/step
# Epoch 17/50
# 156/156 - 1s - loss: 0.2712 - val_loss: 0.2314 - 931ms/epoch - 6ms/step
# Epoch 18/50
# 156/156 - 1s - loss: 0.2349 - val_loss: 0.1985 - 938ms/epoch - 6ms/step
# Epoch 19/50
# 156/156 - 1s - loss: 0.2138 - val_loss: 0.1779 - 945ms/epoch - 6ms/step
# Epoch 20/50
# 156/156 - 1s - loss: 0.1987 - val_loss: 0.1965 - 934ms/epoch - 6ms/step
# Epoch 21/50
# 156/156 - 1s - loss: 0.1808 - val_loss: 0.1508 - 934ms/epoch - 6ms/step
# Epoch 22/50
# 156/156 - 1s - loss: 0.1908 - val_loss: 0.1427 - 970ms/epoch - 6ms/step
# Epoch 23/50
# 156/156 - 1s - loss: 0.1670 - val_loss: 0.1088 - 938ms/epoch - 6ms/step
# Epoch 24/50
# 156/156 - 1s - loss: 0.1830 - val_loss: 0.1357 - 929ms/epoch - 6ms/step
# Epoch 25/50
# 156/156 - 1s - loss: 0.1409 - val_loss: 0.1212 - 945ms/epoch - 6ms/step
# Epoch 26/50
# 156/156 - 1s - loss: 0.1419 - val_loss: 0.1137 - 941ms/epoch - 6ms/step
# Epoch 27/50
# 156/156 - 1s - loss: 0.1270 - val_loss: 0.1099 - 939ms/epoch - 6ms/step
# Epoch 28/50
# 156/156 - 1s - loss: 0.1247 - val_loss: 0.0729 - 943ms/epoch - 6ms/step
# Epoch 29/50
# 156/156 - 1s - loss: 0.2019 - val_loss: 0.1781 - 947ms/epoch - 6ms/step
# Epoch 30/50
# 156/156 - 1s - loss: 0.1274 - val_loss: 0.1075 - 947ms/epoch - 6ms/step
# Epoch 31/50
# 156/156 - 1s - loss: 0.1174 - val_loss: 0.0968 - 941ms/epoch - 6ms/step
# Epoch 32/50
# 156/156 - 1s - loss: 0.0978 - val_loss: 0.0938 - 950ms/epoch - 6ms/step
# Epoch 33/50
# 156/156 - 1s - loss: 0.0947 - val_loss: 0.0911 - 949ms/epoch - 6ms/step
# Epoch 34/50
# 156/156 - 1s - loss: 0.0920 - val_loss: 0.0884 - 943ms/epoch - 6ms/step
# Epoch 35/50
# 156/156 - 1s - loss: 0.0895 - val_loss: 0.0864 - 932ms/epoch - 6ms/step
# Epoch 36/50
# 156/156 - 1s - loss: 0.0875 - val_loss: 0.0846 - 941ms/epoch - 6ms/step
# Epoch 37/50
# 156/156 - 1s - loss: 0.0857 - val_loss: 0.0828 - 939ms/epoch - 6ms/step
# Epoch 38/50
# 156/156 - 1s - loss: 0.0839 - val_loss: 0.0812 - 941ms/epoch - 6ms/step
# Epoch 39/50
# 156/156 - 1s - loss: 0.0825 - val_loss: 0.0799 - 944ms/epoch - 6ms/step
# Epoch 40/50
# 156/156 - 1s - loss: 0.0810 - val_loss: 0.0786 - 934ms/epoch - 6ms/step
# Epoch 41/50
# 156/156 - 1s - loss: 0.0797 - val_loss: 0.0774 - 941ms/epoch - 6ms/step
# Epoch 42/50
# 156/156 - 1s - loss: 0.0787 - val_loss: 0.0764 - 943ms/epoch - 6ms/step
# Epoch 43/50
# 156/156 - 1s - loss: 0.0778 - val_loss: 0.1046 - 948ms/epoch - 6ms/step
# Epoch 44/50
# 156/156 - 1s - loss: 0.0771 - val_loss: 0.0745 - 941ms/epoch - 6ms/step
# Epoch 45/50
# 156/156 - 1s - loss: 0.0762 - val_loss: 0.0738 - 937ms/epoch - 6ms/step
# Epoch 46/50
# 156/156 - 1s - loss: 0.0749 - val_loss: 0.0729 - 935ms/epoch - 6ms/step
# Epoch 47/50
# 156/156 - 1s - loss: 0.1144 - val_loss: 0.0976 - 935ms/epoch - 6ms/step
# Epoch 48/50
# 156/156 - 1s - loss: 0.0906 - val_loss: 0.0716 - 1s/epoch - 7ms/step
# Epoch 49/50
# 156/156 - 1s - loss: 0.0880 - val_loss: 0.0704 - 938ms/epoch - 6ms/step
# Epoch 50/50
# 156/156 - 1s - loss: 0.0969 - val_loss: 0.0695 - 959ms/epoch - 6ms/step

# %%
# make predictions
ypred = model.predict(X_test)
ypred = ypred.round()

from sklearn.metrics import classification_report
print(classification_report(y_test, ypred))
# Out:
# 3/3 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        27
#            1       1.00      0.98      0.99        41
#
#     accuracy                           0.99        68
#    macro avg       0.98      0.99      0.98        68
# weighted avg       0.99      0.99      0.99        68
